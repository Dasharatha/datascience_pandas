# %%
import pandas as pd
df = pd.read_csv('NSMES1988.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# visits          int64
# nvisits         int64
# ovisits         int64
# novisits        int64
# emergency       int64
# hospital        int64
# health         object
# chronic         int64
# adl            object
# region         object
# age           float64
# afam           object
# gender         object
# married        object
# school          int64
# income        float64
# employed       object
# insurance      object
# medicaid       object
# dtype: object

# %%
num_column = df.select_dtypes("int").columns

# %%
num_column = df.select_dtypes("float").columns

# %%
df[num_column]=df[num_column].astype("int8")

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# visits         int64
# nvisits        int64
# ovisits        int64
# novisits       int64
# emergency      int64
# hospital       int64
# health        object
# chronic        int64
# adl           object
# region        object
# age             int8
# afam          object
# gender        object
# married       object
# school         int64
# income          int8
# employed      object
# insurance     object
# medicaid      object
# dtype: object

# %%
df
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0              1       5        0        0         0          0         1
# 1              2       1        0        2         0          2         0
# 2              3      13        0        0         0          3         3
# 3              4      16        0        5         0          1         1
# 4              5       3        0        0         0          0         0
# ...          ...     ...      ...      ...       ...        ...       ...
# 4401        4402      11        0        0         0          0         0
# 4402        4403      12        0        0         0          0         0
# 4403        4404      10        0       20         0          1         1
# 4404        4405      16        1        0         0          0         0
# 4405        4406       0        0        0         0          0         0
#
#          health  chronic      adl region  age afam  gender married  school  \
# ...

# %%
df['age'] = df['age']*10
df['income'] = df['income']*10000
df
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0              1       5        0        0         0          0         1
# 1              2       1        0        2         0          2         0
# 2              3      13        0        0         0          3         3
# 3              4      16        0        5         0          1         1
# 4              5       3        0        0         0          0         0
# ...          ...     ...      ...      ...       ...        ...       ...
# 4401        4402      11        0        0         0          0         0
# 4402        4403      12        0        0         0          0         0
# 4403        4404      10        0       20         0          1         1
# 4404        4405      16        1        0         0          0         0
# 4405        4406       0        0        0         0          0         0
#
#          health  chronic      adl region  age afam  gender married  school  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       visits      nvisits      ovisits     novisits  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean   2203.500000     5.774399     1.618021     0.750794     0.536087
# std    1272.046972     6.759225     5.317056     3.652759     3.879506
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1102.250000     1.000000     0.000000     0.000000     0.000000
# 50%    2203.500000     4.000000     0.000000     0.000000     0.000000
# 75%    3304.750000     8.000000     1.000000     0.000000     0.000000
# max    4406.000000    89.000000   104.000000   141.000000   155.000000
#
#          emergency     hospital      chronic          age       school  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean      0.263504     0.295960     1.541988    69.223786    10.290286
# std       0.703659     0.746398     1.349632     7.365061     3.738736
# ...

# %%
df[['visits', 'gender']].groupby('gender')
df.groupby('gender').agg({'visits':'value_counts'})
# Out:
#                visits
# gender visits
# female 0          354
#        1          298
#        2          247
#        3          239
#        4          237
# ...               ...
# male   63           1
#        65           1
#        66           1
#        68           1
#        89           1
#
# [95 rows x 1 columns]

# %%
df.groupby('gender').agg({'visits':'sum'})
# Out:
#         visits
# gender
# female   15805
# male      9637

# %%
df.groupby('health').agg({'income':'mean'})
# Out:
#                 income
# health
# average    7327.936164
# excellent  4869.224490
# poor       5207.220217

# %%
df.groupby('region').agg({'visits':'mean'})
# Out:
#              visits
# region
# midwest    5.408816
# northeast  6.091995
# other      5.578067
# west       6.368421

# %% [markdown]
# Observation:
# Female made more visits then male
# People from the west made more visits

# %%
df.describe()
# Out:
#         Unnamed: 0       visits      nvisits      ovisits     novisits  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean   2203.500000     5.774399     1.618021     0.750794     0.536087
# std    1272.046972     6.759225     5.317056     3.652759     3.879506
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1102.250000     1.000000     0.000000     0.000000     0.000000
# 50%    2203.500000     4.000000     0.000000     0.000000     0.000000
# 75%    3304.750000     8.000000     1.000000     0.000000     0.000000
# max    4406.000000    89.000000   104.000000   141.000000   155.000000
#
#          emergency     hospital      chronic          age       school  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean      0.263504     0.295960     1.541988    69.223786    10.290286
# std       0.703659     0.746398     1.349632     7.365061     3.738736
# ...

# %%
import seaborn as sns

# %%
df.plot(kind='scatter', x='income', y='age')
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %%
sns.scatterplot(x=df['income'], y=df['age'], alpha=.6, hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %%
df.corr()
# Out:
#             Unnamed: 0    visits   nvisits   ovisits  novisits  emergency  \
# Unnamed: 0    1.000000 -0.021873  0.009741 -0.000072  0.015489  -0.002922
# visits       -0.021873  1.000000  0.226365  0.068144  0.078468   0.158748
# nvisits       0.009741  0.226365  1.000000  0.001129  0.041768   0.049056
# ovisits      -0.000072  0.068144  0.001129  1.000000  0.466923   0.065388
# novisits      0.015489  0.078468  0.041768  0.466923  1.000000   0.024083
# emergency    -0.002922  0.158748  0.049056  0.065388  0.024083   1.000000
# hospital      0.012327  0.240789  0.050401  0.110573  0.065301   0.476061
# chronic       0.002928  0.261886  0.037113  0.100805  0.040748   0.203845
# age          -0.004586  0.006879 -0.036210 -0.042633 -0.032389   0.054369
# school       -0.033246  0.064433  0.085974 -0.012156 -0.011733  -0.071192
# income       -0.022633 -0.017607  0.010690  0.001884  0.015108  -0.021680
#
#             hospital   chronic       age    school    income
# ...

# %%
df[['income','age']].corr()
# Out:
#           income       age
# income  1.000000 -0.056257
# age    -0.056257  1.000000

# %% [markdown]
# Observation:
# Income and age has slight negative corelation which means when age increases, income decreases

# %%
df.sample(5)
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 3438        3439       4       11        0         0          2         0
# 1691        1692      14        2        0         1          1         1
# 1047        1048       7        5        0         0          0         0
# 954          955       1        1        0         0          0         0
# 2466        2467       5        1        4         3          0         0
#
#        health  chronic      adl     region  age afam  gender married  school  \
# 3438     poor        4  limited       west   80   no    male     yes      14
# 1691  average        2   normal       west   70   no  female      no       7
# 1047     poor        1   normal  northeast   60   no  female     yes      12
# 954   average        2   normal      other   60   no    male     yes      14
# 2466  average        1   normal       west   70   no  female      no      11
#
#       income employed insurance medicaid
# ...

# %%
df.groupby('health').describe()
# Out:
#           Unnamed: 0                                                          \
#                count         mean          std   min     25%     50%     75%
# health
# average       3509.0  2199.842120  1271.908557   1.0  1106.0  2185.0  3289.0
# excellent      343.0  2289.472303  1243.577667  31.0  1197.5  2352.0  3389.5
# poor           554.0  2173.440433  1290.312594   3.0  1039.0  2240.0  3326.0
#
#                    visits            ... school        income               \
#               max   count      mean  ...    75%   max   count         mean
# health                               ...
# average    4405.0  3509.0  5.510687  ...   12.0  18.0  3509.0  7327.936164
# excellent  4406.0   343.0  3.428571  ...   14.0  18.0   343.0  4869.224490
# poor       4396.0   554.0  8.897112  ...   12.0  18.0   554.0  5207.220217
#
#
#                     std      min  25%      50%      75%      max
# health
# average    13977.410501 -32144.0  0.0  10000.0  20000.0  32320.0
# ...

# %%
df.groupby('income').describe()
# Out:
#        Unnamed: 0                                                              \
#             count         mean          std     min      25%     50%      75%
# income
# -32144        3.0  2801.000000   572.443010  2470.0  2470.50  2471.0  2966.50
# -31072       23.0  2579.913043  1248.244983   428.0  1487.00  2348.0  3818.50
# -26608        1.0   403.000000          NaN   403.0   403.00   403.0   403.00
# -25536      255.0  2367.333333  1225.005008    43.0  1477.50  2300.0  3429.50
# -22144        1.0  3448.000000          NaN  3448.0  3448.00  3448.0  3448.00
# -21072       15.0  1326.333333   791.075458   393.0   571.50  1457.0  1668.50
# -16608        9.0  2825.111111  1302.836180   999.0  2234.00  3142.0  3918.00
# -15536      159.0  2185.918239  1177.711302    51.0  1318.00  2338.0  3076.00
# -11072        8.0  3077.875000  1293.490895  1100.0  2147.75  3441.5  4133.50
# -10000        2.0   910.500000     0.707107   910.0   910.25   910.5   910.75
# ...
